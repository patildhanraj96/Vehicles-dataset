# %% [markdown]
# # Data set name- Vehicles data
# ##            About features of vehicle dat set :cars
# 1) Name / Brand - Name of the cars
#
# 2) Year - Year of the car when it was bought
#
# 3) selling_price - Price at which the car is being
#
# 4) km_driven - Number of Kilometres the car is driven
#
# 5) fuel - Fuel type of car
#
# 6) seller_type - tells if a seller is individual or a dealer
#
# 7) transmission - Gear transmission fo the car
#
# 8) owner - Number of previous owners of the car
#
# 9) mileage_kmpl - mileage in km per litre of fuel
#
# 10) engine_CC - engine size in cubic cm
#
# 11) max_power_bhp - max break horse power of car
#
# 12) seats - no of seats available in car
#
# 13) torque_Nm - torque genrated by car
#
# 14) RPM - revolution per minute (speed) of car

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.options.display.max_rows = 7000

# %% [markdown]
# # Reading the data and look into the data

# %%
cars = pd.read_excel("C:\\Users\\hp\\Documents\\project\\carsdata.xlsx")
cars
# Out:
#          name                   model  year  selling_price  km_driven    fuel  \
# 0      Maruti         Swift Dzire VDI  2014         450000     145500  Diesel
# 1       Skoda  Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2       Honda      City 2017-2020 Exi  2006         158000     140000  Petrol
# 3     Hyundai       i20 Sportz Diesel  2010         225000     127000  Diesel
# 4      Maruti         Swift VXI BSIII  2007         130000     120000  Petrol
# ...       ...                     ...   ...            ...        ...     ...
# 7901  Hyundai               i20 Magna  2013         320000     110000  Petrol
# 7902  Hyundai           Verna CRDi SX  2007         135000     119000  Diesel
# 7903   Maruti         Swift Dzire ZDi  2009         382000     120000  Diesel
# 7904     Tata              Indigo CR4  2013         290000      25000  Diesel
# 7905     Tata              Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   model          7906 non-null   object
#  2   year           7906 non-null   int64
#  3   selling_price  7906 non-null   int64
#  4   km_driven      7906 non-null   int64
#  5   fuel           7906 non-null   object
#  6   seller_type    7906 non-null   object
#  7   transmission   7906 non-null   object
#  8   owner          7906 non-null   object
#  9   mileage_kmpl   7906 non-null   float64
#  10  engine_CC      7906 non-null   int64
#  11  max_power_bhp  7906 non-null   float64
#  12  seats          7906 non-null   int64
#  13  torque_Nm      7906 non-null   float64
#  14  RPM            7906 non-null   int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 926.6+ KB

# %% [markdown]
# #### Shape of the dataset

# %%
cars.shape
# Out:
# (7906, 15)

# %% [markdown]
# ### Now, let's have a look at the number of unique values in every column

# %%
cars.nunique()
# Out:
# name               31
# model            1983
# year               27
# selling_price     670
# km_driven         898
# fuel                4
# seller_type         3
# transmission        2
# owner               5
# mileage_kmpl      381
# engine_CC         121
# max_power_bhp     318
# seats               9
# torque_Nm         212
# RPM                62
# dtype: int64

# %% [markdown]
# ### Lets change the column name from "name" to "brand"

# %%
cars.rename(columns = {'name':'brand'}, inplace = True)

# %%
cars.head(50)
# Out:
#             brand                                 model  year  selling_price  \
# 0          Maruti                       Swift Dzire VDI  2014         450000
# 1           Skoda                Rapid 1.5 TDI Ambition  2014         370000
# 2           Honda                    City 2017-2020 Exi  2006         158000
# 3         Hyundai                     i20 Sportz Diesel  2010         225000
# 4          Maruti                       Swift VXI BSIII  2007         130000
# 5         Hyundai                 Xcent 1.2 VTVT E Plus  2017         440000
# 6          Maruti                 Wagon R LXI DUO BSIII  2007          96000
# 7          Maruti                           800 DX BSII  2001          45000
# 8          Toyota                             Etios VXD  2011         350000
# 9            Ford       Figo Diesel Celebration Edition  2013         200000
# 10        Renault               Duster 110PS Diesel RxL  2014         500000
# ...

# %% [markdown]
# ###  Lets create new column name as "age" of car.

# %%
cars['age'] = 2021 - cars.year
cars.head()
# Out:
#      brand                   model  year  selling_price  km_driven    fuel  \
# 0   Maruti         Swift Dzire VDI  2014         450000     145500  Diesel
# 1    Skoda  Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2    Honda      City 2017-2020 Exi  2006         158000     140000  Petrol
# 3  Hyundai       i20 Sportz Diesel  2010         225000     127000  Diesel
# 4   Maruti         Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage_kmpl  engine_CC  \
# 0  Individual       Manual   First Owner         23.40       1248
# 1  Individual       Manual  Second Owner         21.14       1498
# 2  Individual       Manual   Third Owner         17.70       1497
# 3  Individual       Manual   First Owner         23.00       1396
# 4  Individual       Manual   First Owner         16.10       1298
#
#    max_power_bhp  seats  torque_Nm   RPM  age
# 0          74.00      5      190.0  2000    7
# ...

# %%
cars.describe()
# Out:
#               year  selling_price     km_driven  mileage_kmpl    engine_CC  \
# count  7906.000000   7.906000e+03  7.906000e+03   7906.000000  7906.000000
# mean   2013.983936   6.498137e+05  6.918866e+04     19.419861  1458.708829
# std       3.863695   8.135827e+05  5.679230e+04      4.036263   503.893057
# min    1994.000000   2.999900e+04  1.000000e+00      0.000000   624.000000
# 25%    2012.000000   2.700000e+05  3.500000e+04     16.780000  1197.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     19.300000  1248.000000
# 75%    2017.000000   6.900000e+05  9.542500e+04     22.320000  1582.000000
# max    2020.000000   1.000000e+07  2.360457e+06     42.000000  3604.000000
#
#        max_power_bhp        seats    torque_Nm          RPM          age
# count    7906.000000  7906.000000  7906.000000  7906.000000  7906.000000
# mean       91.587374     5.416393   177.221682  2913.519605     7.016064
# std        35.747216     0.959208    90.741894   945.608517     3.863695
# ...

# %% [markdown]
# ### If suppose we want to see the cars available as per recent year trend

# %%
z= cars.sort_values(by = 'year', ascending = False)
z
# Out:
#            brand                           model  year  selling_price  \
# 102         Ford  Freestyle Titanium Petrol BSIV  2020         400000
# 1919       Honda            Civic ZX Diesel BSIV  2020        2125000
# 6679      Maruti                    Alto 800 VXI  2020         360000
# 7283     Hyundai                    Santro Magna  2020         500000
# 3118      Maruti                    Alto 800 LXI  2020         350000
# ...          ...                             ...   ...            ...
# 6741      Maruti                          800 AC  1996          42000
# 3985      Maruti                          800 DX  1996          40000
# 3773      Maruti                         800 Std  1995          55000
# 1428      Maruti                          800 AC  1994          45000
# 4577  Ambassador          Classic 2000 DSZ AC PS  1994          99000
#
#       km_driven    fuel seller_type transmission         owner  mileage_kmpl  \
# ...

# %% [markdown]
# # EDA PART :

# %% [markdown]
# ###  Visualization of Average selling price of cars by brand

# %%
x= cars.groupby('brand')['selling_price'].mean().nlargest(8000).plot.bar(color='darkorange',figsize=(14,6))
plt.xlabel('Brand names',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('mean selling price',fontsize=15)
plt.title("brand wise frequency diagram",fontsize=20)
plt.show()

# %% [markdown]
#  * By this graph we can conclude that Lexus brand of cars is expensive among all brands .

# %% [markdown]
# ### Graphical representation of torque values and count

# %%
sns.set_style(style='whitegrid')
sns.displot(cars['torque_Nm'])
plt.xlabel('Brand names',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('mean selling price',fontsize=15)
plt.title("most available torque values ")
plt.show()

# %% [markdown]
# we can conclude that most of the cars having the torque value in the range of 50 to 200 Nm

# %% [markdown]
# ### Graphical representation of type of owner and its count

# %%
owner=cars['owner'].value_counts()
owner
# Out:
# First Owner             5215
# Second Owner            2016
# Third Owner              510
# Fourth & Above Owner     160
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
sns.barplot(owner,owner.index,palette ='tab10')
plt.xlabel('Count')
plt.title("Most available owner types ",fontsize=16)
plt.show()

# %% [markdown]
# ### Figure out the number of cars according to its brand

# %%
cars['brand'].value_counts()
# Out:
# Maruti           2367
# Hyundai          1360
# Mahindra          758
# Tata              719
# Honda             466
# Toyota            452
# Ford              388
# Chevrolet         230
# Renault           228
# Volkswagen        185
# BMW               118
# Skoda             104
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               41
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Kia                 4
# Ambassador          4
# MG                  3
# Daewoo              3
# Ashok               1
# Opel                1
# Name: brand, dtype: int64

# %%
plt.figure(figsize=(16,8))
cars['brand'].value_counts().plot(kind='bar',color='cyan',edgecolor='black',alpha=0.9)
plt.xlabel('Number of cars',fontsize=15)
plt.ylabel('brand',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("brand wise frequency diagram")
plt.show()

# %% [markdown]
# By above graph we can conclude that availability of maruti brand is more.

# %% [markdown]
# ### Figure out the frequency of  number of  seats in cars .

# %%
cars.seats.value_counts()
# Out:
# 5     6254
# 7     1120
# 8      235
# 4      133
# 9       80
# 6       62
# 10      19
# 2        2
# 14       1
# Name: seats, dtype: int64

# %%
cars['seats'].value_counts().plot(kind='barh',color='red',edgecolor='Black',figsize=(20,8))
plt.ylabel('Seats Count',fontsize=25)
plt.xlabel('Number of vehicles',fontsize=25)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Seats count vs frequency of vehicles",fontsize=25)
plt.show()

# %% [markdown]
# ### Here we are trying to find fuel counts

# %%
sns.countplot(cars['fuel'])
plt.title("fuel and its count",fontsize='15')
plt.xlabel("Fuel",fontsize='15')
plt.ylabel("Count",fontsize='15')
plt.xticks(fontsize='15')
plt.yticks(fontsize='15')
plt.show()

# %% [markdown]
# ### Lets find out average selling price of cars by fuel type

# %%
pd.pivot_table(cars,values = 'selling_price',index = 'fuel', aggfunc = 'mean')
# Out:
#         selling_price
# fuel
# CNG     317903.788462
# Diesel  802450.282624
# LPG     210885.714286
# Petrol  472665.203125

# %% [markdown]
# * we can conclude that diesel cars are expensive than other fuel cars

# %%
x = cars.groupby(by = ['fuel','brand']).brand.count()
x
# Out:
# fuel    brand
# CNG     Hyundai             4
#         Maruti             47
#         Tata                1
# Diesel  Ambassador          4
#         Ashok               1
#         Audi               35
#         BMW               115
#         Chevrolet         129
#         Fiat               33
#         Force               6
#         Ford              287
#         Honda             139
#         Hyundai           528
#         Isuzu               5
#         Jaguar             71
#         Jeep               20
#         Kia                 4
#         Land                6
#         Mahindra          726
#         Maruti            860
#         Mercedes-Benz      40
#         Mitsubishi         14
#         Nissan             48
#         Renault           109
#         Skoda              58
#         Tata              530
#         Toyota            334
#         Volkswagen        131
#         Volvo              66
# LPG     Chevrolet           2
# ...

# %% [markdown]
# ### Lets find out LPG fuel cars

# %%
LPG_cars=cars[cars.fuel == 'LPG']
LPG_cars
# Out:
#           brand                               model  year  selling_price  \
# 6        Maruti               Wagon R LXI DUO BSIII  2007          96000
# 86       Maruti                Wagon R LXI LPG BSIV  2010         225000
# 842      Maruti                     Wagon R Duo Lxi  2012         231000
# 1464     Maruti                     Wagon R Duo Lxi  2012         300000
# 1608     Maruti               Wagon R LXI DUO BSIII  2007         105000
# 1853    Hyundai                 Santro Xing GLS LPG  2011         250000
# 2046     Maruti               Wagon R LXI DUO BSIII  2008         170000
# 2101     Maruti               Wagon R LXI DUO BSIII  2010         200000
# 2403    Hyundai                 Santro Xing GLS LPG  2010         150000
# 2435     Maruti                Wagon R LXI LPG BSIV  2010         275000
# 2493     Maruti                     Wagon R Duo Lxi  2011         300000
# 2502     Maruti                     Wagon R Duo Lxi  2010         160000
# ...

# %% [markdown]
# #### basic informations of LPG fuel cars

# %%
p=LPG_cars.iloc[:,0:5]
p
# Out:
#           brand                               model  year  selling_price  \
# 6        Maruti               Wagon R LXI DUO BSIII  2007          96000
# 86       Maruti                Wagon R LXI LPG BSIV  2010         225000
# 842      Maruti                     Wagon R Duo Lxi  2012         231000
# 1464     Maruti                     Wagon R Duo Lxi  2012         300000
# 1608     Maruti               Wagon R LXI DUO BSIII  2007         105000
# 1853    Hyundai                 Santro Xing GLS LPG  2011         250000
# 2046     Maruti               Wagon R LXI DUO BSIII  2008         170000
# 2101     Maruti               Wagon R LXI DUO BSIII  2010         200000
# 2403    Hyundai                 Santro Xing GLS LPG  2010         150000
# 2435     Maruti                Wagon R LXI LPG BSIV  2010         275000
# 2493     Maruti                     Wagon R Duo Lxi  2011         300000
# 2502     Maruti                     Wagon R Duo Lxi  2010         160000
# ...

# %% [markdown]
# ### Now we will plot regression plot of RPM against torque.

# %%
sns.regplot(x='torque_Nm', y="RPM", data=cars)
plt.xlabel("torque_Nm",fontsize='12')
plt.ylabel("RPM",fontsize='12')
plt.xticks(fontsize='12')
plt.yticks(fontsize='12')
plt.title("Scatter plot of Torque vs RPM")
plt.show()

# %% [markdown]
# * we are not getting any linear relation but as per graph we can predict dat generally, As the RPM goes up, the toque value decreasing.

# %%
## If you want to filter the data based on a lower limit and upper limit you can make use of the between function

cars[cars.seats.between(6,10)].head(50)
# Out:
#           brand                                     model  year  \
# 15       Maruti                           Ertiga SHVS VDI  2016
# 26    Chevrolet                   Enjoy TCDi LTZ 7 Seater  2013
# 28       Maruti                      Omni E MPI STD BS IV  2018
# 37         Tata                   Safari DICOR 2.2 LX 4x2  2011
# 45       Toyota                           Fortuner 4x4 MT  2014
# 46       Toyota      Innova 2.5 G (Diesel) 7 Seater BS IV  2013
# 49   Mitsubishi                          Pajero Sport 4X4  2013
# 53       Toyota              Innova Crysta 2.8 ZX AT BSIV  2016
# 54       Toyota            Innova 2.5 G (Diesel) 7 Seater  2016
# 73       Toyota                           Fortuner 4x4 MT  2015
# 75       Maruti                                Ertiga ZXI  2012
# 77       Toyota           Innova 2.5 VX (Diesel) 8 Seater  2016
# 99       Maruti               Eeco 7 Seater Standard BSIV  2016
# 101    Mahindra                Scorpio VLX AT AIRBAG BSIV  2014
# ...

# %%
cars[cars.seats.between(6,10, inclusive = False)].head(20)
# 6 &10 will not include
# Out:
#           brand                                 model  year  selling_price  \
# 15       Maruti                       Ertiga SHVS VDI  2016         778000
# 26    Chevrolet               Enjoy TCDi LTZ 7 Seater  2013         300000
# 28       Maruti                  Omni E MPI STD BS IV  2018         254999
# 37         Tata               Safari DICOR 2.2 LX 4x2  2011         425000
# 45       Toyota                       Fortuner 4x4 MT  2014        1500000
# 46       Toyota  Innova 2.5 G (Diesel) 7 Seater BS IV  2013         700000
# 49   Mitsubishi                      Pajero Sport 4X4  2013        1090000
# 53       Toyota          Innova Crysta 2.8 ZX AT BSIV  2016        1650000
# 54       Toyota        Innova 2.5 G (Diesel) 7 Seater  2016         950000
# 73       Toyota                       Fortuner 4x4 MT  2015        1700000
# 75       Maruti                            Ertiga ZXI  2012         450000
# ...

# %% [markdown]
# ### Lets find out total km driven by cars : Brandwise

# %%
car_brand = cars.groupby('brand')
total_km = car_brand.mean()['km_driven']

# %%
choice_cars= [brand for brand , cars in car_brand]
plt.figure(figsize=(20,8))
plt.bar(choice_cars, total_km)
plt.xticks(choice_cars, rotation ='vertical', fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Brand_name',fontsize=15)
plt.ylabel('Total_km travelled',fontsize=15)
plt.xticks(fontsize=15,rotation=90)
plt.title("Fuel wise brand of cars",fontsize=20)
plt.show()

# %% [markdown]
# ### Let's create a pivot table to summarise our cars data

# %%
pd.pivot_table(cars,values = 'age',index = 'model', aggfunc = 'max')
# Out:
#                                  age
# model
# 3 Series 320d                      4
# 3 Series 320d Corporate Edition    9
# 3 Series 320d GT Luxury Line       4
# 3 Series 320d Highline            12
# 3 Series 320d Luxury Line         11
# ...                              ...
# i20 Sportz 1.4 CRDi                9
# i20 Sportz AT 1.4                  8
# i20 Sportz Diesel                 11
# i20 Sportz Option 1.2              7
# i20 Sportz Option 1.4 CRDi         6
#
# [1983 rows x 1 columns]

# %%
cars['count']=cars['model']
sell=pd.pivot_table(cars,values = ['count'],index = ['seller_type','fuel'], aggfunc = 'count')
sell.sort_values(by = 'count', inplace = True)
sell=sell.reset_index()
sell
# Out:
#         seller_type    fuel  count
# 0            Dealer     LPG      1
# 1        Individual     LPG     34
# 2  Trustmark Dealer  Diesel     34
# 3        Individual     CNG     52
# 4  Trustmark Dealer  Petrol    202
# 5            Dealer  Petrol    415
# 6            Dealer  Diesel    691
# 7        Individual  Petrol   2903
# 8        Individual  Diesel   3574

# %%
g=sns.catplot(hue='fuel',x='seller_type',kind='count',data=cars,height=10,aspect=1.5,palette="hls")
plt.xticks(fontsize=20)#,rotation=90)
plt.yticks(fontsize=20)
plt.title("Fuel wise brand of cars",fontsize=25)
plt.xlabel('seller_type',fontsize=20)
plt.ylabel('Count',fontsize=20)
g._legend.remove()
plt.legend(fontsize=20,loc=1)
plt.show()

# %%
pd.pivot_table(cars, values = 'km_driven', index = 'seller_type', aggfunc = ['max','min'])
# Out:
#                        max       min
#                  km_driven km_driven
# seller_type
# Dealer              221889      1303
# Individual         2360457         1
# Trustmark Dealer     79328      2286

# %% [markdown]
# ### Lets create a pie chart for seller type

# %%
seller_type = cars.groupby(by = 'seller_type')['seller_type'].count()
seller_type
# Out:
# seller_type
# Dealer              1107
# Individual          6563
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
explode = [0.2, 0.2, 0.2]

# %%
plt.pie(seller_type, labels = ['Dealer','Individual','Trustmark Dealer'], autopct='%1.1f%%', radius =2,shadow=True,
        startangle = 180, explode=explode)
plt.title('Most poplular sellers',fontsize = 20)
plt.show()

# %%
cars['count of group']=cars['model']

# %%
no=cars.pivot_table(values=['count of group'],index=['brand','fuel'],aggfunc='count')
no.sort_values(by = 'count of group', inplace = True, ascending = False)
n=no.reset_index()
n
# Out:
#             brand    fuel  count of group
# 0          Maruti  Petrol            1441
# 1          Maruti  Diesel             860
# 2         Hyundai  Petrol             814
# 3        Mahindra  Diesel             726
# 4            Tata  Diesel             530
# 5         Hyundai  Diesel             528
# 6          Toyota  Diesel             334
# 7           Honda  Petrol             327
# 8            Ford  Diesel             287
# 9            Tata  Petrol             188
# 10          Honda  Diesel             139
# 11     Volkswagen  Diesel             131
# 12      Chevrolet  Diesel             129
# 13        Renault  Petrol             119
# 14         Toyota  Petrol             118
# 15            BMW  Diesel             115
# 16        Renault  Diesel             109
# 17           Ford  Petrol             101
# 18      Chevrolet  Petrol              99
# 19         Jaguar  Diesel              71
# 20          Volvo  Diesel              66
# ...

# %%
g=sns.catplot(hue='fuel',x='brand',kind='count',data=cars,height=18,aspect=2.5)
plt.xticks(fontsize=45,rotation=90)
plt.yticks(fontsize=45)
plt.title("Fuel wise brand of cars",fontsize=50)
g._legend.remove()
plt.legend(fontsize=35,loc=1)
plt.show()

# %%
countplot, ax=plt.subplots(figsize=(20,5))
ax=sns.countplot(hue='fuel',x='brand',data=cars)
plt.xticks(fontsize=15,rotation=90)
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+1,rect.get_height(),horizontalalignment='center',fontsize=11)
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %% [markdown]
# ### Lets create bar plot of RPM and its frequency

# %%
cars.RPM.plot(figsize = (12,5), kind = 'hist', fontsize = 15, color = 'lavender', linestyle = '-',edgecolor='Black' )
plt.title('Distribution of RPM',fontsize = 25)
plt.legend(loc = 'upper right')
plt.xlabel('RPM')
plt.show()

# %%
cars.corr()
# Out:
#                    year  selling_price  km_driven  mileage_kmpl  engine_CC  \
# year           1.000000       0.412302  -0.428548      0.328544   0.018263
# selling_price  0.412302       1.000000  -0.222158     -0.126280   0.455682
# km_driven     -0.428548      -0.222158   1.000000     -0.172980   0.206031
# mileage_kmpl   0.328544      -0.126280  -0.172980      1.000000  -0.576408
# engine_CC      0.018263       0.455682   0.206031     -0.576408   1.000000
# max_power_bhp  0.226598       0.749674  -0.038159     -0.374621   0.703975
# seats         -0.007923       0.041617   0.227259     -0.451700   0.611103
# torque_Nm      0.175729       0.622571   0.083185     -0.258415   0.724271
# RPM            0.067114      -0.084585  -0.253419     -0.082566  -0.339017
# age           -1.000000      -0.412302   0.428548     -0.328544  -0.018263
#
#                max_power_bhp     seats  torque_Nm       RPM       age
# year                0.226598 -0.007923   0.175729  0.067114 -1.000000
# ...

# %%
plt.figure(figsize=(12, 6))
heatmap = sns.heatmap(cars.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# ### Plotting of scatter plot

# %%
cars.plot(x = 'torque_Nm',y = 'max_power_bhp',kind='scatter', figsize = (10,6),marker = 'P', s = 40,color='red')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Scatter plot of max_power_bhp vs torque_Nm",fontsize=15)
plt.show()

# %% [markdown]
# by above scatter plot we can conclude that as max power of engine is increases torque value is increases

# %%
cars.plot(x = 'age',y = 'selling_price',kind='scatter', figsize = (10,6),marker = 'D', s = 40,color='Green')
plt.title("Scatter plot of selling price vs Age",fontsize=15)
plt.show()

# %% [markdown]
# by above scatter plot we can conclude that as of car is increases selling price of car is decreses.

# %% [markdown]
# ### now we will find extract only integer and float values from dataset

# %%
x=cars.select_dtypes(include = ["int64", "float64"])
x
# Out:
#       year  selling_price  km_driven  mileage_kmpl  engine_CC  max_power_bhp  \
# 0     2014         450000     145500         23.40       1248          74.00
# 1     2014         370000     120000         21.14       1498         103.52
# 2     2006         158000     140000         17.70       1497          78.00
# 3     2010         225000     127000         23.00       1396          90.00
# 4     2007         130000     120000         16.10       1298          88.20
# ...    ...            ...        ...           ...        ...            ...
# 7901  2013         320000     110000         18.50       1197          82.85
# 7902  2007         135000     119000         16.80       1493         110.00
# 7903  2009         382000     120000         19.30       1248          73.90
# 7904  2013         290000      25000         23.57       1396          70.00
# 7905  2013         290000      25000         23.57       1396          70.00
#
#       seats  torque_Nm   RPM  age
# ...

# %% [markdown]
# ### let suppose if we have to find the cars which are having 2015 and 2016 year and having RPM>4500

# %%
new_df = x[((x['year']==2016)|(x['year'] == 2017)) & (x['RPM'] >4500)]
new_df
# Out:
#       year  selling_price  km_driven  mileage_kmpl  engine_CC  max_power_bhp  \
# 103   2017         866000      37800          17.0       1591          121.3
# 137   2017         795000      41000          18.0       1497          117.6
# 144   2016         805000      49900          16.3       1797          147.5
# 153   2017         875000      18000          15.6       1497          116.3
# 365   2016         550000      56494          18.2       1199           88.7
# ...    ...            ...        ...           ...        ...            ...
# 7829  2016         526000      15000          18.7       1199           88.7
# 7834  2016         575000      55161          17.8       1497          117.3
# 7836  2016         625000      55000          17.8       1497          117.3
# 7842  2016         750000      16151          17.8       1497          117.3
# 7843  2016         890000      40000          14.8       1591          121.3
#
#       seats  torque_Nm   RPM  age
# ...

# %%
new_df["torque_Nm"].hist(color='yellow',edgecolor='black')
plt.ylabel('torque cars',fontsize=12)
plt.xlabel('Number of vehicles',fontsize=12)
plt.title("Torque frequency of cars",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
new_df['max_power_bhp'].hist(color='red')
plt.ylabel('count',fontsize=12)
plt.xlabel('max_power_bhp',fontsize=12)
plt.title("Max power counts",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### if suppose we want to find the cars between years 2019 and 2020 only.

# %%
latest_models = cars[cars.year.between(2019,2020)]
latest_models
# Out:
#         brand                          model  year  selling_price  km_driven  \
# 33     Maruti      Alto 800 CNG LXI Optional  2019         330000      10000
# 34     Maruti            Alto K10 VXI Airbag  2019         366000      15000
# 35    Hyundai       Verna VTVT 1.6 SX Option  2019        1149000       5000
# 39       Jeep  Compass 1.4 Limited Plus BSIV  2019        2100000       5000
# 64     Maruti               Baleno Delta 1.2  2019         650000      30000
# ...       ...                            ...   ...            ...        ...
# 7746   Maruti              Ciaz Alpha Diesel  2019        1025000      32000
# 7758   Maruti                S-Presso VXI AT  2019         475000       5000
# 7768     Ford          Figo 1.2P Titanium MT  2019         530000       9500
# 7770   Maruti              Ciaz Alpha Diesel  2019        1025000      32000
# 7886      Kia           Seltos HTX Plus AT D  2019        1575000      20000
#
# ...

# %%
latest_models.nsmallest(10,'km_driven')
# Out:
#         brand                    model  year  selling_price  km_driven  \
# 2869   Maruti            Swift AMT VXI  2020         654000       1000
# 6455   Toyota  Innova Crysta 2.4 ZX AT  2020        2300000       1000
# 7224   Maruti                Swift LXI  2020         445000       1000
# 7283  Hyundai             Santro Magna  2020         500000       1000
# 7376   Maruti                Swift LXI  2020         445000       1000
# 5990   Datsun              RediGO SV 1  2019         325000       1300
# 125     Honda           Amaze S i-VTEC  2019         690000       1303
# 1512    Honda           Amaze S i-VTEC  2019         690000       1303
# 1802    Honda           Amaze S i-VTEC  2019         690000       1303
# 3135    Honda           Amaze S i-VTEC  2019         690000       1303
#
#         fuel seller_type transmission        owner  mileage_kmpl  engine_CC  \
# 2869  Petrol  Individual    Automatic  First Owner         21.21       1197
# ...

# %% [markdown]
# ## For ola drivers

# %% [markdown]
# ### Let suppose we have to find out the cars on the basis of mileage and its selling price.for a cab service of OLA / UBER . Their requirement is as follows

# %%
ola=cars[((cars['year']==2018)|(cars['year'] == 2019)) & (cars['selling_price'] <500000) & (cars['fuel']== 'CNG')&
         (cars['mileage_kmpl']>25)]

# %%
ola
# Out:
#        brand                      model  year  selling_price  km_driven fuel  \
# 33    Maruti  Alto 800 CNG LXI Optional  2019         330000      10000  CNG
# 2430  Maruti            Wagon R LXI CNG  2018         390000      40000  CNG
# 2444  Maruti            Wagon R LXI CNG  2018         459999      70000  CNG
# 2678  Maruti            Wagon R LXI CNG  2018         450000      50000  CNG
# 5626  Maruti           Alto K10 LXI CNG  2019         430000      20000  CNG
# 6308  Maruti   Wagon R LXI CNG Optional  2019         459999      35000  CNG
# 6970  Maruti            Wagon R LXI CNG  2018         400000      60000  CNG
# 7332  Maruti  Alto 800 CNG LXI Optional  2019         330000      10000  CNG
#
#      seller_type transmission         owner  mileage_kmpl  engine_CC  \
# 33    Individual       Manual  Second Owner         33.44        796
# 2430  Individual       Manual   First Owner         26.60        998
# ...

# %%
ola.set_index('model',inplace=True)

# %%
ola["mileage_kmpl"].plot(kind='bar',figsize = (6,4),color='magenta',edgecolor='black')
plt.ylabel('Mileage of cars',fontsize = 15)
plt.xlabel('Number of vehicles',fontsize = 15)
plt.title("Mileage of each car",fontsize = 15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Executive Class

# %% [markdown]
# ### Let suppose we have to find out the cars on the basis of owner , brand and km driven. and fuel for executives of public sector units .

# %%
executive = cars[((cars['fuel']=='Petrol')|(cars['fuel'] == 'CNG')) & (cars['owner'] >'First Owner') &
                 (cars['brand']=='Ford')|(cars['brand']=='Hyundai') &(cars['km_driven']<15000)]
executive
# Out:
#         brand                              model  year  selling_price  \
# 31    Hyundai             i20 1.2 Asta Dual Tone  2018         730000
# 35    Hyundai           Verna VTVT 1.6 SX Option  2019        1149000
# 63       Ford              Figo 1.2P Titanium MT  2017         600000
# 102      Ford     Freestyle Titanium Petrol BSIV  2020         400000
# 170   Hyundai                      i20 Magna 1.2  2016         550000
# ...       ...                                ...   ...            ...
# 7534  Hyundai  Venue SX Plus Dual Tone Turbo DCT  2019        1150000
# 7733  Hyundai                       Creta 1.6 SX  2018        1220000
# 7757  Hyundai                       Creta 1.6 SX  2018        1220000
# 7782     Ford             Fiesta 1.4 ZXi Duratec  2011         240000
# 7839  Hyundai                Creta 1.6 SX Option  2018        1175000
#
#       km_driven    fuel       seller_type transmission         owner  \
# ...

# %%
sns.catplot(hue='fuel',x='brand',kind='count',data=executive,height=4,aspect=1)
plt.xticks(fontsize=12,rotation=90)
plt.yticks(fontsize=12)
plt.title("Locality wise average rating",fontsize=15)
plt.show()

# %%
executive.seats.value_counts()
# Out:
# 5    134
# Name: seats, dtype: int64

# %%
executive.corr()
# Out:
#                    year  selling_price  km_driven  mileage_kmpl  engine_CC  \
# year           1.000000       0.630923  -0.787127      0.590765  -0.320378
# selling_price  0.630923       1.000000  -0.527621      0.101808   0.266756
# km_driven     -0.787127      -0.527621   1.000000     -0.639106   0.357468
# mileage_kmpl   0.590765       0.101808  -0.639106      1.000000  -0.598691
# engine_CC     -0.320378       0.266756   0.357468     -0.598691   1.000000
# max_power_bhp  0.095442       0.656570  -0.015800     -0.421286   0.690695
# seats               NaN            NaN        NaN           NaN        NaN
# torque_Nm      0.004629       0.517355   0.052545      0.026785   0.586061
# RPM            0.432429       0.158400  -0.317414     -0.069097  -0.125174
# age           -1.000000      -0.630923   0.787127     -0.590765   0.320378
#
#                max_power_bhp  seats  torque_Nm       RPM       age
# year                0.095442    NaN   0.004629  0.432429 -1.000000
# ...

# %% [markdown]
# ### if we have to find out correlation values <.50 or <-.50

# %%
correlation=executive.corr()[((executive.corr()>0.50) | (executive.corr()<-.50)) & (executive.corr()<1)].dropna(axis=0, how='all')
correlation
# Out:
#                    year  selling_price  km_driven  mileage_kmpl  engine_CC  \
# year                NaN       0.630923  -0.787127      0.590765        NaN
# selling_price  0.630923            NaN  -0.527621           NaN        NaN
# km_driven     -0.787127      -0.527621        NaN     -0.639106        NaN
# mileage_kmpl   0.590765            NaN  -0.639106           NaN  -0.598691
# engine_CC           NaN            NaN        NaN     -0.598691        NaN
# max_power_bhp       NaN       0.656570        NaN           NaN   0.690695
# torque_Nm           NaN       0.517355        NaN           NaN   0.586061
# RPM                 NaN            NaN        NaN           NaN        NaN
# age           -1.000000      -0.630923   0.787127     -0.590765        NaN
#
#                max_power_bhp  seats  torque_Nm       RPM       age
# year                     NaN    NaN        NaN       NaN -1.000000
# selling_price       0.656570    NaN   0.517355       NaN -0.630923
# ...

# %% [markdown]
# #### Lets create few scatter plot for executive conditions

# %%
executive.plot(x = 'age',y = 'km_driven',kind='scatter', figsize = (8,4), marker = 'P', s = 50)
plt.xlabel('Age',fontsize=14)
plt.ylabel('km_driven',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("Scatter plot of Age vs Km driven",fontsize=15)
plt.show()

# %% [markdown]
# we can conclude that as age of car is incraeses distance covered by car is also increases (positive correlation)

# %%
executive.plot(x = 'mileage_kmpl',y = 'RPM',kind='scatter', figsize = (6,4), marker = 'P', s = 50)
plt.xlabel('Mileage_kmpl',fontsize=14)
plt.ylabel('RPM',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("Scateer plot of RPM vd Mileage",fontsize=15)
plt.show()

# %% [markdown]
# from above scatter plot we can predict that as RPM of car is increases mileage of car decreases.

# %%
executive['engine_CC'].plot(kind='hist', orientation='vertical',figsize = (8,4),color='yellow',edgecolor='black') 
plt.xlabel('engine size in CC',fontsize=14)
plt.ylabel('Number of vehicles',fontsize=14)
plt.title("Engine size frequency of vehicles",fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
executive.mileage_kmpl.hist(color = 'red',edgecolor='black',figsize=(8,4))
plt.title('Mileage wise Distribution',fontsize = 20)
plt.ylabel('Count ',fontsize = 15)
plt.xlabel('Mileage of cars',fontsize = 15)
plt.show()

# %% [markdown]
# from this graph we can conclude that most of the cars having mileage in the range of 18 to 21 kmpl.

# %%
executive.year.value_counts()
# Out:
# 2019    42
# 2018    26
# 2017    21
# 2016     9
# 2020     6
# 2014     5
# 2010     4
# 2013     3
# 2015     3
# 2003     3
# 2011     3
# 2009     2
# 2012     2
# 2004     1
# 2008     1
# 2007     1
# 2006     1
# 2005     1
# Name: year, dtype: int64

# %%
executive['year'].value_counts().plot(kind='bar',figsize = (15,4),fontsize = 14,color= 'red')
plt.xlabel('year',fontsize = 13)
plt.ylabel('count',fontsize = 13)
plt.title("Year wise frequency of cars")
plt.show()

# %%
executive['selling_price'].hist(color='violet',edgecolor='black')
plt.ylabel('count')
plt.xlabel('selling price')
plt.title("selling price frequency of cars")
plt.show()

# %% [markdown]
# we can conculde that selling price of most cars lies between 5 to 8 lakhs.

# %% [markdown]
# ### If customer wants only JEEP as brand

# %%
bc= cars[cars['brand'] == 'Jeep']
bc
# Out:
#      brand                            model  year  selling_price  km_driven  \
# 39    Jeep    Compass 1.4 Limited Plus BSIV  2019        2100000       5000
# 129   Jeep       Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# 511   Jeep  Compass 2 Longitude Option BSIV  2018        1600000      14000
# 552   Jeep                Compass 2 Limited  2017        1650000      50000
# 1367  Jeep            Compass 2 Limited 4X4  2017        1950000      70000
# 1516  Jeep       Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# 1716  Jeep  Compass 2 Longitude Option BSIV  2018        1675000      80000
# 1806  Jeep       Wrangler 2016-2019 3.6 4X4  2017        4100000      17000
# 1978  Jeep  Compass 2 Longitude Option BSIV  2017        1689999      60000
# 2706  Jeep         Compass 2 Limited Option  2017        1325000      30000
# 2743  Jeep              Compass 1.4 Limited  2019        1450000      22000
# ...

# %%
bc.set_index('model',inplace=True)

# %%
bc.age.plot.bar(color="darkblue",figsize=(10,4))
plt.ylabel('age of jeep',fontsize = 15)
plt.xlabel('Model of jeep',fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title("Age vs Model graph",fontsize = 15)
plt.show()

# %%
bc.shape
# Out:
# (31, 16)

# %%
bc.max_power_bhp.plot(kind = 'hist', figsize = (8,4),color='magenta',edgecolor='black')
plt.ylabel('Number of cars',fontsize = 15)
plt.xlabel('Max bhp of cars',fontsize = 15)
plt.title("Distribution of max bhp with frequency",fontsize = 15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
bc.km_driven.plot(kind = 'bar', figsize = (10,4))
plt.ylabel('km_driven by cars',fontsize = 13)
plt.xlabel('car models',fontsize = 13)
plt.title("km_driven vs car model",fontsize = 15)
plt.show()

# %% [markdown]
# ### Lets suppose customer wants cars for Government officers -
# ### (made in india brand will be preffered)

# %%
gov = cars[(cars['seats']==7) & ((cars['brand'] == 'Tata')|(cars['brand']=='Mahindra')) & (cars['torque_Nm'] > 150)]
gov
# Out:
#          brand                        model  year  selling_price  km_driven  \
# 37        Tata      Safari DICOR 2.2 LX 4x2  2011         425000      60000
# 106   Mahindra        XUV500 W11 Option AWD  2019        1700000      32000
# 204       Tata                      Hexa XE  2019        1250000      15000
# 211       Tata             Safari Storme EX  2017         800000      60000
# 224   Mahindra         Ssangyong Rexton RX5  2013         900000      70000
# ...        ...                          ...   ...            ...        ...
# 7798      Tata      New Safari Dicor VX 4X2  2006         300000     175000
# 7802  Mahindra   Bolero 2011-2019 EX NON AC  2014         600000      70000
# 7810      Tata                 Sumo Gold EX  2014         275000     300000
# 7859      Tata  New Safari DICOR 2.2 EX 4x2  2010         300000     100000
# 7878  Mahindra                XUV500 W8 2WD  2013         750000     120000
#
# ...

# %%
gov['owner'].value_counts().plot(kind='bar')
plt.xlabel('Owner type',fontsize = 13)
plt.ylabel('Count',fontsize = 13)
plt.yticks(fontsize=13)
plt.xticks(fontsize=13)
plt.title("km_driven vs car model",fontsize = 15)
plt.show()

# %%
sns.set_style('whitegrid')
A=sns.countplot(y='owner',hue='brand',data=gov,palette="dark")
plt.xlabel('Counts of car',fontsize = 13)
plt.ylabel('owner ',fontsize = 13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("Owner wise count of cars",fontsize=15)
plt.show()

# %% [markdown]
# #### lets create some pivot table for goverment data

# %%
pd.pivot_table(gov,values = 'age',index = 'owner', aggfunc = 'mean')
# Out:
#                             age
# owner
# First Owner            6.023419
# Fourth & Above Owner  11.000000
# Second Owner           8.654088
# Third Owner           10.090909

# %% [markdown]
# we can observed that avereage age of first owner vehicles is lesser than others.

# %%
pd.pivot_table(gov,values = 'max_power_bhp',index = ['brand','torque_Nm'], aggfunc = 'mean')
# Out:
#                     max_power_bhp
# brand    torque_Nm
# Mahindra 176.0          83.000000
#          180.0          63.000000
#          182.5          63.000000
#          195.0          63.742574
#          200.0          75.000000
#          210.0          74.960000
#          218.0          93.700000
#          230.0         100.000000
#          240.0         100.000000
#          247.0         105.000000
#          260.0         112.000000
#          280.0         119.932000
#          290.0         120.000000
#          300.0         121.000000
#          320.0         140.000000
#          330.0         139.934426
#          340.0         162.000000
#          360.0         153.022143
#          402.0         184.000000
# Tata     190.0          90.000000
#          196.0         127.000000
#          223.0          68.857500
#          250.0          91.733077
#          255.0         120.000000
#          320.0         142.160000
#          400.0         153.860000

# %%
owner= gov.groupby(by = 'owner')['owner'].count()
owner
# Out:
# owner
# First Owner             427
# Fourth & Above Owner     10
# Second Owner            159
# Third Owner              33
# Name: owner, dtype: int64

# %%
plt.pie(owner, labels = ['First Owner','Second Owner','Third Owner','Fourth & Above Owner'],autopct='%1.3f%%',radius= 1.5)
plt.show()

# %%
plt.figure(figsize=(5,6))
sns.barplot(x = "brand", y = "selling_price", hue = "seller_type",ci=0 ,data=gov,palette ='magma')
plt.ylabel("selling_price")
plt.title("owner and its brand vs selling price")
plt.xticks(rotation = 60)
plt.show()

# %%
gov.corr()
# Out:
#                    year  selling_price  km_driven  mileage_kmpl  engine_CC  \
# year           1.000000       0.728213  -0.343874      0.635271  -0.410547
# selling_price  0.728213       1.000000  -0.347404      0.401679  -0.239739
# km_driven     -0.343874      -0.347404   1.000000     -0.258125   0.171113
# mileage_kmpl   0.635271       0.401679  -0.258125      1.000000  -0.551980
# engine_CC     -0.410547      -0.239739   0.171113     -0.551980   1.000000
# max_power_bhp  0.153551       0.419537  -0.041031     -0.203552  -0.171066
# seats               NaN            NaN        NaN           NaN        NaN
# torque_Nm      0.188216       0.486061  -0.056534     -0.163250  -0.096415
# RPM            0.052437       0.276559  -0.029801     -0.174005  -0.255038
# age           -1.000000      -0.728213   0.343874     -0.635271   0.410547
#
#                max_power_bhp  seats  torque_Nm       RPM       age
# year                0.153551    NaN   0.188216  0.052437 -1.000000
# ...

# %%
gov.plot(x = 'age',y = 'selling_price',kind='scatter', figsize = (6,4), marker = 'P', s = 50)
plt.show()

# %% [markdown]
# from the above scatter plot we can conclude that as age is increases  selling price is decreses.

# %% [markdown]
# ### To change plot style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %% [markdown]
# ### Lets suppose customer wants cars which are producing high torque havin number of seats =7

# %%
mountain=cars[(cars['seats']==7) & (cars['torque_Nm'] > 350)]
mountain
# Out:
#            brand                          model  year  selling_price  \
# 49    Mitsubishi               Pajero Sport 4X4  2013        1090000
# 53        Toyota   Innova Crysta 2.8 ZX AT BSIV  2016        1650000
# 106     Mahindra          XUV500 W11 Option AWD  2019        1700000
# 130         Land   Rover Discovery Sport TD4 SE  2019        4500000
# 140         Audi      Q7 35 TDI Quattro Premium  2015        2650000
# ...          ...                            ...   ...            ...
# 7575      Toyota                Fortuner 4x4 AT  2016        1750000
# 7688      Toyota   Innova Crysta 2.8 ZX AT BSIV  2016        1516000
# 7702        Tata                        Hexa XT  2017        1400000
# 7713        Ford  Endeavour 2.2 Titanium AT 4X2  2016        2100000
# 7803     Hyundai                Santa Fe 4x4 AT  2011        1200000
#
#       km_driven    fuel seller_type transmission         owner  mileage_kmpl  \
# ...

# %% [markdown]
# ### Scatter plot of engine size vs mileage of car

# %%
mountain.plot(x = 'mileage_kmpl',y = 'engine_CC',kind='scatter', figsize = (6,5), marker = 'D', s = 50)
plt.show()

# %%
owner_1= mountain.groupby(by = 'brand')['owner'].count()
owner_1
# Out:
# brand
# Audi              6
# BMW               1
# Chevrolet         3
# Ford             11
# Hyundai           5
# Isuzu             2
# Land              4
# Mahindra         18
# Mercedes-Benz     2
# Mitsubishi        7
# Tata             17
# Toyota           41
# Name: owner, dtype: int64

# %%
pd.pivot_table(mountain,values=['brand'],index = ['owner'], aggfunc = 'count')
# Out:
#                       brand
# owner
# First Owner              91
# Fourth & Above Owner      1
# Second Owner             23
# Third Owner               2

# %%
pd.pivot_table(mountain,values=['model'],index = ['brand','owner'], aggfunc = 'count')
# Out:
#                                     model
# brand         owner
# Audi          First Owner               3
#               Fourth & Above Owner      1
#               Second Owner              1
#               Third Owner               1
# BMW           First Owner               1
# Chevrolet     First Owner               1
#               Second Owner              2
# Ford          First Owner               7
#               Second Owner              3
#               Third Owner               1
# Hyundai       First Owner               1
#               Second Owner              4
# Isuzu         First Owner               2
# Land          First Owner               4
# Mahindra      First Owner              17
#               Second Owner              1
# Mercedes-Benz First Owner               2
# Mitsubishi    First Owner               5
#               Second Owner              2
# Tata          First Owner              17
# Toyota        First Owner              31
# ...

# %% [markdown]
# ### Distribution of owners according to brand

# %%
sns.set_style('whitegrid')
sns.catplot(y='brand',hue='owner',kind='count',data=mountain,palette='hls',height=5,aspect=2.5)
plt.xlabel('Counts of car',fontsize = 18)
plt.ylabel('Brand',fontsize = 18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Brand wise count of cars",fontsize=20)
plt.show()

# %% [markdown]
#  So among  all brand Toyota  is looking famous for drive in mountains and hilly areas.
